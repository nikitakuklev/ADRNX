# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys, time
sys.path.append('/home/pi/Desktop/ADR_NX/Utils')
from adr_PID import ADR_PID
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import spline

# %%
P = 1.8
I = 0.0
D = 0.0

pid = ADR_PID(P,I,D,1)
pid.SetPoint=0.0
pid.setSlewLimit(10.0)

END = 80
feedback = 0
debug = 1

feedback_list = []
time_list = []
setpoint_list = []

# %%
for i in range(1, END):
    if i>9:
        pid.SetPoint = 2

    pid.update(feedback)
    output = pid.output
    if pid.SetPoint > 0:
        feedback += (output - (1/i))
    time.sleep(0.02)

    feedback_list.append(feedback)
    setpoint_list.append(pid.SetPoint)
    time_list.append(i)

#time_sm = np.array(time_list)
#time_smooth = np.linspace(time_sm.min(), time_sm.max(), 300)
#feedback_smooth = spline(time_list, feedback_list, time_smooth)
# Out:
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# No slew rate limit - 0.0
# P:0.000|I:0.000|D:0.000|sp:0.00
# Slew rate up limited to 0.207 from 3.600
# P:3.600|I:0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.204 from 3.020
# P:3.227|I:0.000|D:-0.000|sp:2.00
# Slew rate up limited to 0.211 from 2.075
# P:2.486|I:0.000|D:-0.000|sp:2.00
# Slew rate up limited to 0.209 from 0.743
# P:1.366|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.207 from -0.964
# P:-0.132|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.208 from -1.881
# P:-1.256|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.206 from -2.421
# P:-2.005|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.206 from -2.594
# P:-2.384|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.206 from -2.397
# P:-2.392|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.207 from -1.830
# P:-2.031|I:0.000|D:0.000|sp:2.00
# Slew rate down limited to -0.205 from -0.888
# P:-1.296|I:-0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.219 from 0.422
# P:-0.192|I:-0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.205 from 0.912
# P:0.518|I:-0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.206 from 1.046
# P:0.857|I:0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.206 from 0.809
# P:0.826|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.424861049652
# P:0.425|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.204 from -0.765
# P:-0.340|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.204 from -0.958
# P:-0.737|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.205 from -0.783
# P:-0.767|I:-0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.204 from -0.240
# P:-0.428|I:-0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.204 from 0.670
# P:0.278|I:-0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.204 from 0.805
# P:0.617|I:0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.207 from 0.573
# P:0.588|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.187397060394
# P:0.187|I:0.000|D:-0.000|sp:2.00
# Slew rate down limited to -0.204 from -0.337
# P:-0.150|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - -0.119456439972
# P:-0.119|I:0.000|D:0.000|sp:2.00
# Slew rate up limited to 0.204 from 0.215
# P:0.096|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.05686301651
# P:-0.057|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.045490413208
# P:0.045|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.0363923305664
# P:-0.036|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.0291138644531
# P:0.029|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.0232910915625
# P:-0.023|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.01863287325
# P:0.019|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.0149062986
# P:-0.015|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.01192503888
# P:0.012|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.009540031104
# P:-0.010|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.0076320248832
# P:0.008|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.00610561990656
# P:-0.006|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00488449592525
# P:0.005|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.0039075967402
# P:-0.004|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00312607739216
# P:0.003|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.00250086191373
# P:-0.003|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00200068953098
# P:0.002|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.00160055162479
# P:-0.002|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00128044129983
# P:0.001|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.00102435303986
# P:-0.001|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.000819482431891
# P:0.001|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.000655585945513
# P:-0.001|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00052446875641
# P:0.001|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.000419575005128
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.000335660004103
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.000268528003282
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.000214822402626
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.0001718579221
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 0.00013748633768
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -0.000109989070145
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 8.79912561158e-05
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -7.03930048923e-05
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 5.63144039137e-05
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -4.50515231313e-05
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 3.60412185048e-05
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -2.88329748037e-05
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 2.3066379843e-05
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -1.84531038745e-05
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 1.47624830996e-05
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -1.180998648e-05
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 9.44798918381e-06
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -7.55839134721e-06
# P:-0.000|I:0.000|D:-0.000|sp:2.00
# No slew rate limit - 6.04671307785e-06
# P:0.000|I:0.000|D:0.000|sp:2.00
# No slew rate limit - -4.8373704626e-06
# P:-0.000|I:0.000|D:-0.000|sp:2.00

# %%
plt.figure(1)
plt.plot(time_list, feedback_list)
plt.plot(time_list, setpoint_list)
plt.xlim((0, END))
#plt.ylim((min(feedback_list)-0.5, max(feedback_list)+0.5))
#plt.ylim((0,3))
plt.xlabel('time (s)')
plt.ylabel('PID (PV)')
plt.title('TEST PID')

#plt.ylim((1-0.5, 1+0.5))
plt.ylim((0,3))

plt.grid(True)
plt.show()

# %%
plt.figure(2)
plt.plot(time_list, [(feedback_list[i] - setpoint_list[i]) for  i in range(0,len(feedback_list))])
plt.xlim((0, END))
#plt.ylim((min(feedback_list)-0.5, max(feedback_list)+0.5))
#plt.ylim((0,3))
plt.xlabel('time (s)')
plt.ylabel('PID (PV)')
plt.title('TEST PID')

#plt.ylim((1-0.5, 1+0.5))
plt.ylim((0,3))

plt.grid(True)
plt.show()
