# %% [markdown]
# ## ADRNX BB PID DEMO

# %% [markdown]
# ### Initialization (make sure to shut down the magcycle kernel first!!!)

# %%
import serial, threading, sys, time, os, datetime, warnings, numpy as np, matplotlib.pyplot as plt
from IPython.display import display, clear_output
import ipywidgets as widgets
from ipywidgets import FloatProgress, HTML, VBox
from timeit import default_timer as timer

# We will be using our homemade library to talk to ADR and BB via serial
sys.path.append('/home/pi/Desktop/ADRNX/SRS')
import SRS
sys.path.append('/home/pi/Desktop/ADRNX/BBNX')
import HCLib

# %%
# Initialize BB
HC = HCLib.HeaterController.Core(debug=True,override_device='/dev/ADR_hc')
HC.establish_comms()
# Out:
# HCDBG: Port ready: Serial<id=0x746435b0, open=False>(port=None, baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=0.2, xonxoff=False, rtscts=False, dsrdtr=False)
# HCDBG: Platform (linux) -> device list is ['/dev/ADR_hc']
# HCDBG: Starting device search
# HCDBG: Port /dev/ADR_hc incorrect msg:
# HCDBG: Port /dev/ADR_hc incorrect msg:
# HCDBG: Port /dev/ADR_hc incorrect msg: I am HeaterController: 1E 95 F
# HCDBG: Port /dev/ADR_hc incorrect msg: Type: A0
# HCDBG: Port /dev/ADR_hc incorrect msg: FW: 12
# HCDBG: Port /dev/ADR_hc incorrect msg: SN: 11
# HCDBG: Port /dev/ADR_hc incorrect msg: Freq: 16000000
# HCDBG: Port /dev/ADR_hc incorrect msg: Checking EEPROM...TYPE OK...SN OK!
# HCDBG: Port /dev/ADR_hc incorrect msg: Timer 1 setup: TOP=31250 and f=4
# HCDBG: Port /dev/ADR_hc CORRECT msg: HCA011
# HCDBG: Found device on port /dev/ADR_hc -> connected!
# HCDBG: Device READY!

# %%
# Initialize mainframe controller (with config file, suppressing debug statements)
mf = SRS.SIM900.SIM900('/home/pi/Desktop/ADRNX/SRS/config.yaml',debug=False)
mf.init_mainframe()
# Create module objects (coresponding to those in the rack) and add them to mainframe
s921 = SRS.SIM921.SIM921(mf,name='s921',debug=False)
s922 = SRS.SIM922.SIM922(mf,name='s922',debug=False)
s960 = SRS.SIM960.SIM960(mf,name='s960',debug=False)
s970 = SRS.SIM970.SIM970(mf,name='s970',debug=False)
mf.register_and_init_mods([s921, s922, s960, s970])
# Finally, start communication threads (this will enable all the backend virtual queues and messaging)
mf.start_comm_threads()

# %%
def make_bar(minv=0,maxv=1,prefix='Voltage: ',postfix='/2.0V',style='info'):
    progress = FloatProgress(min=minv,max=maxv,step=(maxv-minv)/1000)
    progress.bar_style = style
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)
    
    label.value = prefix+''+postfix
    return [progress, label, box,prefix,postfix]
    
def update_bar(bar,val,fmt='{:.3f}'):
    bar[0].value = val
    bar[1].value = bar[3]+fmt.format(val)+bar[4]
    if val ==  bar[0].max:  
        bar[0].bar_style = 'success'

# %% [markdown]
# ### Actual PID code

# %%
targetT = 20.0 #K
P = targetT*0.7
I = 0.03
D = 0.10
slewlimit = 0.5 #%/s

# %%
pid = HCLib.PID.stockPID(P,I,D,0)
pid.SetPoint = targetT
pid.setSlewLimit(slewlimit)

start = timer()
HC.set_dutycycle(0)
HC.set_onoff(1)
runPID = True

barBB = make_bar(0,targetT+5,prefix='BB temperature: ',postfix='K',style='warning')
barFAA = make_bar(0,500,prefix='FAA temperature: ',postfix='mK',style='info')
barDC = make_bar(0,100,prefix='Duty cycle: ',postfix='%',style='danger')

s921.start_data_stream()
s922.start_data_stream(4)
try:
    while runPID or timer()-start < 10:
        gotevent = s921.await_next_event(tm=2.5,clear_before=False,clear_after=True)
        if not gotevent: raise RuntimeError("No temperature in time - aborting")     
        tempFAA = s921.lastvalues[1]  
        
        gotevent = s922.await_next_event(tm=2.5,clear_before=True,clear_after=True)
        if not gotevent: raise RuntimeError("No temperature in time - aborting")            
        tempBB = s922.lastvalues[4]
        timeBB = s922.lastdatatimes[4] 
                
        # Override if too low or too high
        if targetT > tempBB+3.0:
            output = 100.0
        elif targetT < tempBB-0.2:
            output = 0.0
        else:
            pid.update(tempBB)
            output = pid.output
            
        # Clamp output     
        if output < 0.0:    
            output_actual = 0.0
        elif output > 100.0:
            output_actual = 100.0
        else:
            output_actual = output
            
        update_bar(barDC,output_actual)
        update_bar(barBB,tempBB)
        update_bar(barFAA,tempFAA*1000.0)
        
        HC.set_dutycycle(output_actual)               
        print("{:6.4f}|{:6.4f}|{:6.4f}|{:6.4f}".format(output_actual,output,tempBB,tempFAA))
except Exception as e:
    print(e)
    raise e
finally:
    s922.stop_data_stream()
    s921.stop_data_stream()
    HC.set_dutycycle(0)
    HC.set_onoff(0)
# Out:
# Sending command: |b'SC0000\n'|
# Sending command: |b'ON0000\n'|
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.7360|2.8461
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.7330|2.8282
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.7310|2.8034
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.7460|2.8606
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.7940|2.8587
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.8670|2.8841
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|15.9590|2.8829
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.0660|2.8754
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.1820|2.8861
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.4320|2.8443
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.5630|2.8644
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.6970|2.8609
# Sending command: |b'SC9999\n'|
# 100.0000|100.0000|16.8310|2.8724
# Sending command: |b'SC0590\n'|
# 5.9055|5.9055|17.0990|2.8764
# Sending command: |b'SC0630\n'|
# 6.3009|6.3009|17.2320|2.8885
# Sending command: |b'SC0670\n'|
# 6.7050|6.7050|17.3640|2.8892
# Sending command: |b'SC0709\n'|
# 7.1003|7.1003|17.4870|2.8407
# Sending command: |b'SC0759\n'|
# 7.6003|7.6003|17.6850|2.8421
# Sending command: |b'SC0799\n'|
# 7.9989|7.9989|17.7630|2.8456
# Sending command: |b'SC0840\n'|
# 8.4046|8.4046|17.8310|2.8321
# Sending command: |b'SC0878\n'|
# 8.7882|8.7882|17.8910|2.8257
# Sending command: |b'SC0928\n'|
# 9.2882|9.2882|17.9890|2.8628
# Sending command: |b'SC0968\n'|
# 9.6876|9.6876|18.0320|2.8071
# Sending command: |b'SC1009\n'|
# 10.0911|10.0911|18.0700|2.8011
# Sending command: |b'SC1048\n'|
# 10.4869|10.4869|18.1060|2.8027
# Sending command: |b'SC1098\n'|
# 10.9869|10.9869|18.1670|2.7912
# Sending command: |b'SC1138\n'|
# 11.3906|11.3906|18.1950|2.8054
# Sending command: |b'SC1179\n'|
# 11.7956|11.7956|18.2200|2.8247
# Sending command: |b'SC1218\n'|
# 12.1897|12.1897|18.2440|2.8221
# Sending command: |b'SC1268\n'|
# 12.6897|12.6897|18.2890|2.8190
# Sending command: |b'SC1309\n'|
# 13.0914|13.0914|18.3100|2.8139
# Sending command: |b'SC1347\n'|
# 13.4804|13.4804|18.3300|2.8234
# Sending command: |b'SC1389\n'|
# 13.8933|13.8933|18.3510|2.8157
# Sending command: |b'SC1439\n'|
# 14.3933|14.3933|18.3910|2.8078
# Sending command: |b'SC1478\n'|
# 14.7908|14.7908|18.4120|2.8127
# Sending command: |b'SC1519\n'|
# 15.1991|15.1991|18.4310|2.8146
# Sending command: |b'SC1559\n'|
# 15.5945|15.5945|18.4510|2.8303
# Sending command: |b'SC1609\n'|
# 16.0945|16.0945|18.4900|2.8331
# Sending command: |b'SC1649\n'|
# 16.4960|16.4960|18.5090|2.8234
# Sending command: |b'SC1690\n'|
# 16.9025|16.9025|18.5290|2.8200
# Sending command: |b'SC1729\n'|
# 17.2969|17.2969|18.5480|2.8412
# Sending command: |b'SC1779\n'|
# 17.7969|17.7969|18.5870|2.8160
# Sending command: |b'SC1819\n'|
# 18.1999|18.1999|18.6070|2.8202
# Sending command: |b'SC1860\n'|
# 18.6064|18.6064|18.6260|2.8413
# Sending command: |b'SC1881\n'|
# 18.8167|18.8167|18.6470|2.8016
# Sending command: |b'SC1852\n'|
# 18.5228|18.5228|18.6870|2.7791
# Sending command: |b'SC1836\n'|
# 18.3635|18.3635|18.7080|2.8018
# Sending command: |b'SC1820\n'|
# 18.2048|18.2048|18.7290|2.8152
# Sending command: |b'SC1804\n'|
# 18.0441|18.0441|18.7500|2.8259
# Sending command: |b'SC1771\n'|
# 17.7202|17.7202|18.7920|2.8314
# Sending command: |b'SC1755\n'|
# 17.5588|17.5588|18.8130|2.8093
# Sending command: |b'SC1739\n'|
# 17.3961|17.3961|18.8340|2.8443
# Sending command: |b'SC1721\n'|
# 17.2208|17.2208|18.8560|2.8613
# Sending command: |b'SC1689\n'|
# 16.8988|16.8988|18.8970|2.8406
# Sending command: |b'SC1673\n'|
# 16.7328|16.7328|18.9180|2.8101
# Sending command: |b'SC1657\n'|
# 16.5749|16.5749|18.9380|2.8251
# Sending command: |b'SC1640\n'|
# 16.4067|16.4067|18.9590|2.8509
# Sending command: |b'SC1608\n'|
# 16.0866|16.0866|18.9990|2.8341
# Sending command: |b'SC1593\n'|
# 15.9364|15.9364|19.0180|2.8539
# Sending command: |b'SC1577\n'|
# 15.7757|15.7757|19.0380|2.8658
# Sending command: |b'SC1562\n'|
# 15.6229|15.6229|19.0570|2.8688
# Sending command: |b'SC1532\n'|
# 15.3253|15.3253|19.0940|2.8064
# Sending command: |b'SC1516\n'|
# 15.1693|15.1693|19.1130|2.7750
# Sending command: |b'SC1502\n'|
# 15.0259|15.0259|19.1310|2.7616
# Sending command: |b'SC1487\n'|
# 14.8797|14.8797|19.1490|2.7835
# Sending command: |b'SC1458\n'|
# 14.5854|14.5854|19.1850|2.7815
# Sending command: |b'SC1444\n'|
# 14.4469|14.4469|19.2020|2.8286
# Sending command: |b'SC1430\n'|
# 14.3084|14.3084|19.2190|2.8685
# Sending command: |b'SC1417\n'|
# 14.1786|14.1786|19.2350|2.9227
# Sending command: |b'SC1391\n'|
# 13.9169|13.9169|19.2670|2.9248
# Sending command: |b'SC1378\n'|
# 13.7860|13.7860|19.2830|2.9114
# Sending command: |b'SC1365\n'|
# 13.6542|13.6542|19.2990|2.8875
# Sending command: |b'SC1352\n'|
# 13.5313|13.5313|19.3140|2.8983
# Sending command: |b'SC1326\n'|
# 13.2634|13.2634|19.3460|2.8476
# Sending command: |b'SC1312\n'|
# 13.1291|13.1291|19.3620|2.8298
# Sending command: |b'SC1300\n'|
# 13.0051|13.0051|19.3770|2.8482
# Sending command: |b'SC1287\n'|
# 12.8791|12.8791|19.3920|2.8516
# /home/pi/Desktop/ADRNX/SRS/SIM922.py:122: UserWarning: SIM922 BAD TEMP LENGTH: |'1.94'|
#   warnings.warn("SIM922 BAD TEMP LENGTH: |{}|".format(repr(val)))
# /home/pi/Desktop/ADRNX/SRS/SIM922.py:122: UserWarning: SIM922 BAD TEMP LENGTH: |'0800E+01'|
#   warnings.warn("SIM922 BAD TEMP LENGTH: |{}|".format(repr(val)))
# Sending command: |b'SC1261\n'|
# 12.6152|12.6152|19.4230|2.8431
# Sending command: |b'SC1249\n'|
# 12.4982|12.4982|19.4370|2.8344
# Sending command: |b'SC1237\n'|
# 12.3803|12.3803|19.4510|2.7997
# Sending command: |b'SC1227\n'|
# 12.2712|12.2712|19.4640|2.8352
# Sending command: |b'SC1204\n'|
# 12.0422|12.0422|19.4910|2.8570
# Sending command: |b'SC1193\n'|
# 11.9318|11.9318|19.5040|2.8838
# Sending command: |b'SC1182\n'|
# 11.8213|11.8213|19.5170|2.8689
# Sending command: |b'SC1171\n'|
# 11.7205|11.7205|19.5290|2.8491
# Sending command: |b'SC1150\n'|
# 11.5058|11.5058|19.5540|2.8737
# Sending command: |b'SC1140\n'|
# 11.4036|11.4036|19.5660|2.8982
# Sending command: |b'SC1129\n'|
# 11.3003|11.3003|19.5780|2.9127
# Sending command: |b'SC1119\n'|
# 11.1965|11.1965|19.5900|2.9170
# Sending command: |b'SC1099\n'|
# 10.9979|10.9979|19.6130|2.9070
# Sending command: |b'SC1090\n'|
# 10.9028|10.9028|19.6240|2.8599
# Sending command: |b'SC1080\n'|
# 10.8071|10.8071|19.6350|2.8518
# Sending command: |b'SC1071\n'|
# 10.7119|10.7119|19.6460|2.8587
# Sending command: |b'SC1052\n'|
# 10.5283|10.5283|19.6670|2.8586
# Sending command: |b'SC1042\n'|
# 10.4310|10.4310|19.6780|2.8582
# Sending command: |b'SC1034\n'|
# 10.3441|10.3441|19.6880|2.8714
# Sending command: |b'SC1025\n'|
# 10.2558|10.2558|19.6980|2.8778
# Sending command: |b'SC1007\n'|
# 10.0784|10.0784|19.7180|2.8414
# Sending command: |b'SC0998\n'|
# 9.9894|9.9894|19.7280|2.8782
# Sending command: |b'SC0990\n'|
# 9.9102|9.9102|19.7370|2.8160
# Sending command: |b'SC0981\n'|
# 9.8199|9.8199|19.7470|2.7974
# Sending command: |b'SC0965\n'|
# 9.6586|9.6586|19.7650|2.7956
# Sending command: |b'SC0957\n'|
# 9.5782|9.5782|19.7740|2.7867
# Sending command: |b'SC0949\n'|
# 9.4967|9.4967|19.7830|2.8367
# Sending command: |b'SC0941\n'|
# 9.4148|9.4148|19.7920|2.8133
# Sending command: |b'SC0925\n'|
# 9.2605|9.2605|19.8090|2.7982
# Sending command: |b'SC0917\n'|
# 9.1775|9.1775|19.8180|2.8315
# Sending command: |b'SC0910\n'|
# 9.1047|9.1047|19.8260|2.8157
# Sending command: |b'SC0904\n'|
# 9.0414|9.0414|19.8330|2.8003
# Sending command: |b'SC0890\n'|
# 8.9036|8.9036|19.8480|2.8206
# Sending command: |b'SC0882\n'|
# 8.8292|8.8292|19.8560|2.7904
# Sending command: |b'SC0876\n'|
# 8.7649|8.7649|19.8630|2.7991
# Sending command: |b'SC0870\n'|
# 8.7104|8.7104|19.8690|2.7844
# Sending command: |b'SC0855\n'|
# 8.5592|8.5592|19.8850|2.8422
# Sending command: |b'SC0848\n'|
# 8.4834|8.4834|19.8930|2.8611
# Sending command: |b'SC0840\n'|
# 8.4074|8.4074|19.9010|2.8200
# Sending command: |b'SC0834\n'|
# 8.3412|8.3412|19.9080|2.8108
# Sending command: |b'SC0819\n'|
# 8.1974|8.1974|19.9230|2.8405
# Sending command: |b'SC0812\n'|
# 8.1302|8.1302|19.9300|2.8527
# Sending command: |b'SC0806\n'|
# 8.0628|8.0628|19.9370|2.8482
# Sending command: |b'SC0800\n'|
# 8.0052|8.0052|19.9430|2.8408
# Sending command: |b'SC0787\n'|
# 7.8786|7.8786|19.9560|2.8659
# Sending command: |b'SC0781\n'|
# 7.8203|7.8203|19.9620|2.8462
# Sending command: |b'SC0775\n'|
# 7.7514|7.7514|19.9690|2.8216
# Sending command: |b'SC0770\n'|
# 7.7027|7.7027|19.9740|2.8640
# Sending command: |b'SC0758\n'|
# 7.5837|7.5837|19.9860|2.8895
# Sending command: |b'SC0752\n'|
# 7.5240|7.5240|19.9920|2.8778
# Sending command: |b'SC0746\n'|
# 7.4640|7.4640|19.9980|2.8618
# Sending command: |b'SC0741\n'|
# 7.4142|7.4142|20.0030|2.8121
# Sending command: |b'SC0731\n'|
# 7.3131|7.3131|20.0130|2.8154
# Sending command: |b'SC0726\n'|
# 7.2624|7.2624|20.0180|2.7765
# Sending command: |b'SC0720\n'|
# 7.2012|7.2012|20.0240|2.7875
# Sending command: |b'SC0715\n'|
# 7.1605|7.1605|20.0280|2.7974
# Sending command: |b'SC0705\n'|
# 7.0572|7.0572|20.0380|2.7835
# Sending command: |b'SC0701\n'|
# 7.0158|7.0158|20.0420|2.8262
# Sending command: |b'SC0696\n'|
# 6.9637|6.9637|20.0470|2.7956
# Sending command: |b'SC0691\n'|
# 6.9116|6.9116|20.0520|2.8099
# Sending command: |b'SC0682\n'|
# 6.8270|6.8270|20.0600|2.8526
# Sending command: |b'SC0677\n'|
# 6.7742|6.7742|20.0650|2.8582
# Sending command: |b'SC0673\n'|
# 6.7316|6.7316|20.0690|2.8795
# Sending command: |b'SC0668\n'|
# 6.6887|6.6887|20.0730|2.8455
# Sending command: |b'SC0659\n'|
# 6.5921|6.5921|20.0820|2.8592
# Sending command: |b'SC0655\n'|
# 6.5590|6.5590|20.0850|2.8346
# Sending command: |b'SC0651\n'|
# 6.5152|6.5152|20.0890|2.8244
# Sending command: |b'SC0647\n'|
# 6.4715|6.4715|20.0930|2.8347
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1010|2.8118
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8630
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8161
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1110|2.8478
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1140|2.8439
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1140|2.8601
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1150|2.8487
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1150|2.8407
# s921 | Recovered: |'+2.875662E+00\r'|, buf |+2.8|
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1120|2.8757
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1120|2.8530
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1110|2.8593
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1100|2.8258
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1070|2.8465
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8236
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1030|2.8554
# Sending command: |b'SC0631\n'|
# 6.3157|6.3157|20.1000|2.8673
# Sending command: |b'SC0636\n'|
# 6.3681|6.3681|20.0940|2.9041
# Sending command: |b'SC0639\n'|
# 6.3946|6.3946|20.0910|2.9019
# Sending command: |b'SC0641\n'|
# 6.4108|6.4108|20.0890|2.8947
# Sending command: |b'SC0642\n'|
# 6.4274|6.4274|20.0870|2.9009
# Sending command: |b'SC0643\n'|
# 6.4404|6.4404|20.0850|2.8544
# Sending command: |b'SC0643\n'|
# 6.4367|6.4367|20.0850|2.8342
# Sending command: |b'SC0643\n'|
# 6.4333|6.4333|20.0850|2.8863
# Sending command: |b'SC0641\n'|
# 6.4197|6.4197|20.0860|2.8673
# Sending command: |b'SC0640\n'|
# 6.4028|6.4028|20.0870|2.8580
# Sending command: |b'SC0638\n'|
# 6.3893|6.3893|20.0880|2.8692
# Sending command: |b'SC0637\n'|
# 6.3757|6.3757|20.0890|2.8331
# Sending command: |b'SC0635\n'|
# 6.3519|6.3519|20.0910|2.8270
# Sending command: |b'SC0631\n'|
# 6.3144|6.3144|20.0940|2.8320
# Sending command: |b'SC0628\n'|
# 6.2905|6.2905|20.0960|2.8232
# Sending command: |b'SC0626\n'|
# 6.2666|6.2666|20.0980|2.8371
# Sending command: |b'SC0624\n'|
# 6.2425|6.2425|20.1000|2.8097
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8266
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1070|2.8760
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1090|2.8918
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1110|2.8680
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1130|2.8849
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1130|2.8594
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1130|2.8606
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1120|2.8382
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1090|2.8981
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1070|2.9008
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8310
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1020|2.8567
# Sending command: |b'SC0620\n'|
# 6.2105|6.2105|20.0960|2.8425
# Sending command: |b'SC0624\n'|
# 6.2470|6.2470|20.0920|2.8513
# Sending command: |b'SC0627\n'|
# 6.2733|6.2733|20.0890|2.8344
# Sending command: |b'SC0629\n'|
# 6.2998|6.2998|20.0860|2.8518
# Sending command: |b'SC0634\n'|
# 6.3433|6.3433|20.0810|2.8500
# Sending command: |b'SC0633\n'|
# 6.3395|6.3395|20.0810|2.8428
# Sending command: |b'SC0633\n'|
# 6.3362|6.3362|20.0810|2.8989
# Sending command: |b'SC0634\n'|
# 6.3433|6.3433|20.0800|2.8980
# Sending command: |b'SC0631\n'|
# 6.3163|6.3163|20.0820|2.8439
# Sending command: |b'SC0629\n'|
# 6.2929|6.2929|20.0840|2.8204
# Sending command: |b'SC0628\n'|
# 6.2898|6.2898|20.0840|2.8125
# Sending command: |b'SC0627\n'|
# 6.2762|6.2762|20.0850|2.8467
# Sending command: |b'SC0623\n'|
# 6.2391|6.2391|20.0880|2.8607
# Sending command: |b'SC0622\n'|
# 6.2257|6.2257|20.0890|2.8715
# Sending command: |b'SC0620\n'|
# 6.2018|6.2018|20.0910|2.9020
# Sending command: |b'SC0618\n'|
# 6.1884|6.1884|20.0920|2.9072
# Sending command: |b'SC0613\n'|
# 6.1405|6.1405|20.0960|2.8512
# Sending command: |b'SC0611\n'|
# 6.1166|6.1166|20.0980|2.8250
# Sending command: |b'SC0609\n'|
# 6.0925|6.0925|20.1000|2.7939
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1020|2.7802
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1060|2.7917
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8052
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1100|2.7739
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1100|2.7936
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1100|2.8303
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1090|2.8459
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8532
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1060|2.8708
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1020|2.8598
# Sending command: |b'SC0603\n'|
# 6.0338|6.0338|20.1000|2.8344
# Sending command: |b'SC0605\n'|
# 6.0600|6.0600|20.0970|2.8193
# Sending command: |b'SC0608\n'|
# 6.0863|6.0863|20.0940|2.8406
# Sending command: |b'SC0612\n'|
# 6.1290|6.1290|20.0890|2.8459
# Sending command: |b'SC0613\n'|
# 6.1352|6.1352|20.0880|2.8079
# Sending command: |b'SC0615\n'|
# 6.1520|6.1520|20.0860|2.8175
# Sending command: |b'SC0615\n'|
# 6.1585|6.1585|20.0850|2.8050
# Sending command: |b'SC0615\n'|
# 6.1515|6.1515|20.0850|2.7756
# Sending command: |b'SC0614\n'|
# 6.1480|6.1480|20.0850|2.7456
# Sending command: |b'SC0613\n'|
# 6.1345|6.1345|20.0860|2.7771
# Sending command: |b'SC0613\n'|
# 6.1312|6.1312|20.0860|2.8003
# Sending command: |b'SC0611\n'|
# 6.1141|6.1141|20.0870|2.8349
# /home/pi/Desktop/ADRNX/SRS/SIM922.py:122: UserWarning: SIM922 BAD TEMP LENGTH: |'2.00'|
#   warnings.warn("SIM922 BAD TEMP LENGTH: |{}|".format(repr(val)))
# /home/pi/Desktop/ADRNX/SRS/SIM922.py:122: UserWarning: SIM922 BAD TEMP LENGTH: |'8800E+01'|
#   warnings.warn("SIM922 BAD TEMP LENGTH: |{}|".format(repr(val)))
# Sending command: |b'SC0608\n'|
# 6.0868|6.0868|20.0890|2.8500
# Sending command: |b'SC0607\n'|
# 6.0733|6.0733|20.0900|2.8356
# Sending command: |b'SC0606\n'|
# 6.0699|6.0699|20.0900|2.8261
# Sending command: |b'SC0604\n'|
# 6.0458|6.0458|20.0920|2.8003
# Sending command: |b'SC0601\n'|
# 6.0118|6.0118|20.0950|2.7793
# Sending command: |b'SC0597\n'|
# 5.9779|5.9779|20.0980|2.8227
# Sending command: |b'SC0596\n'|
# 5.9643|5.9643|20.0990|2.8315
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8895
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8774
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1100|2.8679
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1110|2.8887
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1130|2.8362
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1130|2.8476
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1120|2.8536
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1110|2.8505
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8490
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1060|2.8606
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1040|2.8621
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1010|2.8593
# Sending command: |b'SC0592\n'|
# 5.9222|5.9222|20.0960|2.8345
# Sending command: |b'SC0594\n'|
# 5.9486|5.9486|20.0930|2.8159
# Sending command: |b'SC0597\n'|
# 5.9749|5.9749|20.0900|2.8069
# Sending command: |b'SC0600\n'|
# 6.0016|6.0016|20.0870|2.8603
# Sending command: |b'SC0604\n'|
# 6.0447|6.0447|20.0820|2.8417
# Sending command: |b'SC0605\n'|
# 6.0513|6.0513|20.0810|2.8412
# Sending command: |b'SC0605\n'|
# 6.0581|6.0581|20.0800|2.8429
# Sending command: |b'SC0606\n'|
# 6.0649|6.0649|20.0790|2.8679
# Sending command: |b'SC0605\n'|
# 6.0584|6.0584|20.0790|2.8513
# Sending command: |b'SC0605\n'|
# 6.0552|6.0552|20.0790|2.8524
# Sending command: |b'SC0604\n'|
# 6.0419|6.0419|20.0800|2.8586
# Sending command: |b'SC0603\n'|
# 6.0388|6.0388|20.0800|2.8135
# Sending command: |b'SC0600\n'|
# 6.0020|6.0020|20.0830|2.8515
# Sending command: |b'SC0598\n'|
# 5.9888|5.9888|20.0840|2.8528
# Sending command: |b'SC0597\n'|
# 5.9752|5.9752|20.0850|2.8625
# Sending command: |b'SC0596\n'|
# 5.9619|5.9619|20.0860|2.8734
# Sending command: |b'SC0591\n'|
# 5.9144|5.9144|20.0900|2.8987
# Sending command: |b'SC0590\n'|
# 5.9010|5.9010|20.0910|2.8694
# Sending command: |b'SC0587\n'|
# 5.8771|5.8771|20.0930|2.8898
# Sending command: |b'SC0585\n'|
# 5.8534|5.8534|20.0950|2.9153
# Sending command: |b'SC0582\n'|
# 5.8257|5.8257|20.0970|2.9078
# Sending command: |b'SC0580\n'|
# 5.8015|5.8015|20.0990|2.8617
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1010|2.8221
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1020|2.8221
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1050|2.8725
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1070|2.8088
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8568
# Sending command: |b'SC0000\n'|
# 0.0000|0.0000|20.1080|2.8732
# Sending command: |b'SC0000\n'|
# Sending command: |b'OFF000\n'|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-08cd49a7ad1f> in <module>()
#      16 try:
#      17     while runPID or timer()-start < 10:
# ---> 18         gotevent = s921.await_next_event(tm=2.5,clear_before=False,clear_after=True)
#      19         if not gotevent: raise RuntimeError("No temperature in time - aborting")
#      20         tempFAA = s921.lastvalues[1]
#
# ~/Desktop/ADRNX/SRS/SIM_MOD_STREAMER.py in await_next_event(self, tm, clear_before, clear_after)
#      47         if (self.streaming == True):
#      48             if clear_before: self.newdataevent.clear();
# ---> 49             result = self.newdataevent.wait(tm);
#      50             if clear_after: self.newdataevent.clear();
#      51             return result
#
# /usr/lib/python3.4/threading.py in wait(self, timeout)
#     551             signaled = self._flag
#     552             if not signaled:
# --> 553                 signaled = self._cond.wait(timeout)
#     554             return signaled
#     555         finally:
#
# /usr/lib/python3.4/threading.py in wait(self, timeout)
#     292             else:
#     293                 if timeout > 0:
# --> 294                     gotit = waiter.acquire(True, timeout)
#     295                 else:
#     296                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Code below is still in construction, dont use

# %%
def updateSetpoint(b):
    targetT = ftext.value
    pid.SetPoint = targetT
    print(temp)
    

ftext = widgets.BoundedFloatText(
            value=7.5,
            min=0.0,
            max=25.0,
            step=0.1,
            description='Temperature setpoint:',
            disabled=False
        )
html = widgets.HTML(
    value="..........................",
    placeholder="..........................",
)

button = widgets.Button(
    description='Update temperature',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
)
button.on_click(updateSetpoint)
l1 = widgets.Label("0.333")
l2 = widgets.HTML(value="<center>   Hello</center>",)
hb1 = widgets.HBox([ftext,button])
fp = widgets.FloatProgress(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='FAA',
    bar_style='info',
    orientation='vertical'
)
fpfull = widgets.VBox([l2,fp])
fp3 = widgets.HBox([fpfull,fpfull,fpfull])
box = widgets.VBox([hb1,html,fp3])
display(box)

# %%
for i in range(4):
    time.sleep(1)
    fp.description=str(i)
